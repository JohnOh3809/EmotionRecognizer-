# %%
ids = [
    "1TGwKprghhECNyCRJzi7XhbH4O3n0N_Xf",
    "1NqTGKG_9i6c0QmeTb4o2xKlAZSSr1QPA",
    "1qt_C3lqn0MESRRkyp1JvNj23u9kWwrZW",
    "1MHinoWJIU7EdL7Wt6tNHTM-1NtmJUFti",
    "1fxKxU2YjvC9XLcOz4OcvU1_DMJP_kLUc"
]
full_data = "1JsdbBkulkIOqrchyDnML2GEmuwi6E_d2"

# %%
# !gdown {full_data}
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1JsdbBkulkIOqrchyDnML2GEmuwi6E_d2
# From (redirected): https://drive.google.com/uc?id=1JsdbBkulkIOqrchyDnML2GEmuwi6E_d2&confirm=t&uuid=f6dad2d4-3f02-4d25-9b7f-456f239d42b6
# To: /home/ubuntu/caer.zip
# 100%|██████████████████████████████████████| 7.63G/7.63G [02:00<00:00, 63.5MB/s]

# %%
# !sudo apt-get update
# !sudo apt-get install -y wget zip unzip

# !wget -O caer.zip full_data
for fid in ids:
    # !gdown {fid}
# Out:
# Ign:1 http://linux.mellanox.com/public/repo/doca/2.9.3/ubuntu22.04/x86_64 ./ InRelease
# Hit:2 http://linux.mellanox.com/public/repo/doca/2.9.3/ubuntu22.04/x86_64 ./ Release
# Get:3 https://nvidia.github.io/libnvidia-container/stable/deb/amd64  InRelease [1477 B]
# Hit:4 https://download.docker.com/linux/ubuntu jammy InRelease
# Hit:5 https://packages.microsoft.com/repos/azure-cli jammy InRelease
# Hit:7 http://archive.lambdalabs.com/ubuntu jammy InRelease
# Hit:8 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:9 https://pkg.cloudflare.com/cloudflared jammy InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:11 http://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:12 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:13 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:14 https://ppa.launchpadcontent.net/flexiondotorg/nvtop/ubuntu jammy InRelease
# Fetched 1477 B in 1s (1954 B/s)
# ...

# %%
# !zip -s 0 caers_split.zip --out caers.zip
# !unzip caers.zip;
# Out:
#   File "/tmp/ipykernel_3589/3553106605.py", line 1
#     zip -s 0 caers_split.zip --out caers.zip
#            ^
# SyntaxError: invalid syntax

# %%
# !unzip caer.zip;
# Out:
# Archive:  caer.zip
#    creating: CAER/
#    creating: CAER/test/
#    creating: CAER/test/Anger/
#   inflating: CAER/test/Anger/0001.avi
#   inflating: CAER/test/Anger/0002.avi
#   inflating: CAER/test/Anger/0003.avi
#   inflating: CAER/test/Anger/0004.avi
#   inflating: CAER/test/Anger/0005.avi
#   inflating: CAER/test/Anger/0006.avi
#   inflating: CAER/test/Anger/0007.avi
#   inflating: CAER/test/Anger/0008.avi
#   inflating: CAER/test/Anger/0009.avi
#   inflating: CAER/test/Anger/0010.avi
#   inflating: CAER/test/Anger/0011.avi
#   inflating: CAER/test/Anger/0012.avi
#   inflating: CAER/test/Anger/0013.avi
#   inflating: CAER/test/Anger/0014.avi
#   inflating: CAER/test/Anger/0015.avi
#   inflating: CAER/test/Anger/0016.avi
#   inflating: CAER/test/Anger/0017.avi
#   inflating: CAER/test/Anger/0018.avi
#   inflating: CAER/test/Anger/0019.avi
#   inflating: CAER/test/Anger/0020.avi
#   inflating: CAER/test/Anger/0021.avi
#   inflating: CAER/test/Anger/0022.avi
# ...
